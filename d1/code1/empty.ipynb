

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('../input/train.csv')
data.drop('ID',axis=1, inplace=True)
data
df_test = pd.read_csv('../input/test.csv')

# %%
data.iloc[tr_lines]
# Out:
#      SUBCLASS    A2M   AAAS AADAT AARS1 ABAT   ABCA1   ABCA2 ABCA3   ABCA4  \
# 141      LUSC     WT     WT    WT    WT   WT      WT      WT    WT      WT
# 286      STES     WT  L395P    WT    WT   WT      WT      WT    WT      WT
# 353     KIPAN     WT     WT    WT    WT   WT      WT      WT    WT      WT
# 539      STES     WT     WT    WT    WT   WT      WT      WT    WT      WT
# 679      STES     WT     WT  W86L    WT   WT  G592fs      WT    WT    R24H
# 911      COAD     WT     WT    WT    WT   WT      WT      WT    WT      WT
# 1494     SKCM     WT     WT    WT    WT   WT      WT  S1705F    WT   Y633N
# 1586     COAD     WT     WT    WT    WT   WT      WT      WT    WT      WT
# 1813     BRCA     WT     WT    WT    WT   WT      WT      WT    WT      WT
# 1860     BRCA     WT     WT    WT    WT   WT      WT      WT    WT      WT
# 2080     SKCM     WT     WT    WT    WT   WT      WT      WT    WT      WT
# ...

# %%
data.iloc[tr_top_lines]['SUBCLASS'].value_counts()
# Out:
# SUBCLASS
# BRCA      158
# UCEC       39
# KIPAN      18
# GBMLGG     16
# CESC       16
# COAD       15
# KIRC       12
# HNSC       12
# LGG        11
# STES       10
# BLCA        8
# LIHC        5
# LUAD        4
# DLBC        3
# PRAD        3
# SKCM        3
# LUSC        2
# OV          2
# SARC        2
# ACC         1
# PCPG        1
# TGCT        1
# Name: count, dtype: int64

# %%
data.iloc[tr_left_lines]['SUBCLASS'].value_counts()
# Out:
# SUBCLASS
# THCA      176
# SKCM       30
# BRCA       17
# PRAD       12
# CESC        9
# GBMLGG      9
# KIPAN       8
# PCPG        6
# LUAD        4
# LIHC        4
# KIRC        4
# TGCT        3
# STES        3
# HNSC        3
# SARC        3
# COAD        3
# LGG         2
# BLCA        2
# PAAD        1
# UCEC        1
# OV          1
# THYM        1
# DLBC        1
# LAML        1
# ACC         1
# Name: count, dtype: int64

# %%
tr_line2 = [ 679, 5145, 5173, 5205]
data.iloc[tr_line2]['SUBCLASS'].value_counts()
# Out:
# SUBCLASS
# STES    1
# SKCM    1
# UCEC    1
# COAD    1
# Name: count, dtype: int64

# %%
tr_lines3=  [ 71,  601, 1502, 1758, 1761, 2795, 3090, 3679, 3967, 4385, 4966,
       5049, 5566, 5682]

# %%
data.iloc[tr_lines3]['SUBCLASS'].value_counts()
# Out:
# SUBCLASS
# UCEC    3
# STES    3
# COAD    3
# CESC    2
# SKCM    1
# BLCA    1
# LUAD    1
# Name: count, dtype: int64

# %%
for t in tar : 
    #print(t, df_test.iloc[t].apply(lambda x : 1 if x!='WT' else 0).agg(sum))
    res_nw['SUBCLASS'][t]='COAD'
#res_nw.to_csv('res-forced-BRCA-02.csv',index=False)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/2811672398.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   res_nw['SUBCLASS'][t]='COAD'

# %%
res_nw.SUBCLASS.value_counts()
# Out:
# SUBCLASS
# COAD      736
# BRCA      539
# KIPAN     193
# STES      159
# GBMLGG    122
# OV        104
# THCA       69
# KIRC       66
# LGG        63
# HNSC       57
# UCEC       55
# SKCM       52
# CESC       41
# PRAD       40
# PCPG       35
# TGCT       34
# LAML       32
# SARC       29
# LIHC       29
# LUAD       24
# PAAD       22
# BLCA       21
# ACC        12
# LUSC        7
# THYM        5
# Name: count, dtype: int64

# %%
cgs = pd.read_csv('../input/cancer-genes.csv')

# %%
# 'WT'가 아닌 값이 있는 컬럼명을 각 행에 대해 추출하는 함수
def get_non_wt_columns(row):
    return list(row.index[row != 'WT'])

# 각 행에서 'WT'가 아닌 열의 컬럼명을 리스트로 저장
#test non_wt_columns = df_test.iloc[:, 1:].apply(get_non_wt_columns, axis=1)
non_wt_columns = pd.DataFrame()
non_wt_columns['SUBCLASS'] = data['SUBCLASS']
non_wt_columns['gset'] = data.iloc[:,2:].apply(get_non_wt_columns, axis=1).reset_index(name='gset').drop('index',axis=1)

#non_wt_columns.sort_values(by=['SUBCLASS'], inplace=True)

# %%
non_wt_columns
# Out:
#      SUBCLASS                                               gset
# 0       KIPAN  [ABCC2, ADCY2, CD86, EPHB4, FOXC2, GBF1, GLMN,...
# 1        SARC  [ABCC8, ATRX, DTX1, FN3K, GPR182, HELZ2, INCEN...
# 2        SKCM  [ABCB11, ABCC8, ABL1, ACTC1, ACTN2, ADAM15, AD...
# 3        KIRC      [EGFR, EIF4G2, F5, LAMB3, SLC4A4, TPH1, ZEB1]
# 4      GBMLGG  [AHNAK, ALOX15B, C8B, CACNA1H, CAD, CALCR, CAS...
# ...       ...                                                ...
# 6196     LUAD  [ABCB8, ACSL4, ACTC1, ALMS1, APBB2, AVPR1A, B3...
# 6197      LGG  [ADD2, AVPR1A, FLT4, HTR5A, IKZF1, KCNJ2, LAS1...
# 6198     COAD  [ADAM2, ADD2, APC, ATP2B4, COL5A3, COL9A1, DMD...
# 6199     TGCT  [ARHGAP4, HIBCH, IGSF1, ITGAL, TRIO, WASF2, YW...
# 6200     SKCM  [ABCA9, ABL1, ADAMDEC1, ATXN1, BCAN, BRAF, CAC...
#
# [6201 rows x 2 columns]

# %%
cset =  set(cgs['c.genes'].values)

# %%
non_wt_columns['inters'] = non_wt_columns['gset'].apply(lambda x: len(set(x).intersection(cset)))

# %%
non_wt_columns
# Out:
#      SUBCLASS                                               gset  inters
# 0       KIPAN  [ABCC2, ADCY2, CD86, EPHB4, FOXC2, GBF1, GLMN,...       4
# 1        SARC  [ABCC8, ATRX, DTX1, FN3K, GPR182, HELZ2, INCEN...       7
# 2        SKCM  [ABCB11, ABCC8, ABL1, ACTC1, ACTN2, ADAM15, AD...      13
# 3        KIRC      [EGFR, EIF4G2, F5, LAMB3, SLC4A4, TPH1, ZEB1]       1
# 4      GBMLGG  [AHNAK, ALOX15B, C8B, CACNA1H, CAD, CALCR, CAS...       6
# ...       ...                                                ...     ...
# 6196     LUAD  [ABCB8, ACSL4, ACTC1, ALMS1, APBB2, AVPR1A, B3...       6
# 6197      LGG  [ADD2, AVPR1A, FLT4, HTR5A, IKZF1, KCNJ2, LAS1...       5
# 6198     COAD  [ADAM2, ADD2, APC, ATP2B4, COL5A3, COL9A1, DMD...       5
# 6199     TGCT  [ARHGAP4, HIBCH, IGSF1, ITGAL, TRIO, WASF2, YW...       0
# 6200     SKCM  [ABCA9, ABL1, ADAMDEC1, ATXN1, BCAN, BRAF, CAC...       8
#
# [6201 rows x 3 columns]

# %%
non_wt_columns[non_wt_columns.inters==0].SUBCLASS.value_counts()
# Out:
# SUBCLASS
# BRCA      117
# PRAD       92
# THCA       85
# KIPAN      83
# KIRC       65
# THYM       61
# PCPG       57
# LAML       56
# SARC       48
# GBMLGG     45
# LGG        34
# TGCT       16
# CESC       14
# OV         12
# STES       12
# LIHC        8
# ACC         7
# PAAD        7
# SKCM        5
# LUAD        4
# HNSC        4
# UCEC        3
# LUSC        2
# DLBC        2
# BLCA        1
# Name: count, dtype: int64

# %%
non_wt_columns[non_wt_columns.inters==0]
# Out:
#      SUBCLASS                                               gset  inters
# 17      KIPAN                                              [VHL]       0
# 18       BRCA                                           [B3GNT3]       0
# 20     GBMLGG                                            [SYNE1]       0
# 43     GBMLGG             [COL15A1, IDH1, ITIH3, SLC23A1, SYNJ1]       0
# 48       STES  [ACHE, AFAP1L2, AOC3, CACNA1H, CASP2, CMTR1, E...       0
# ...       ...                                                ...     ...
# 6171   GBMLGG                       [IDH1, PDE6B, SEC14L1, ZW10]       0
# 6173     PRAD            [ADAMDEC1, MYH1, POLA1, TMPRSS6, TRIM5]       0
# 6186    KIPAN  [ACSL4, AGFG1, APPBP2, ATF6, CADM2, DEPTOR, EI...       0
# 6189     TGCT                                [IGSF3, MMP1, TLR1]       0
# 6199     TGCT  [ARHGAP4, HIBCH, IGSF1, ITGAL, TRIO, WASF2, YW...       0
#
# [840 rows x 3 columns]

# %%
for d in data.SUBCLASS.unique():
    print(d, non_wt_columns[non_wt_columns['SUBCLASS']== d]['gset'].apply(lambda x: 'AHNAK' in x if isinstance(x, list) else False).agg(sum))
# Out:
# KIPAN 15
# SARC 9
# SKCM 51
# KIRC 5
# GBMLGG 11
# STES 45
# BRCA 24
# THCA 3
# LIHC 8
# HNSC 24
# PAAD 5
# OV 10
# PRAD 7
# UCEC 21
# LAML 0
# COAD 18
# ACC 0
# LGG 2
# LUSC 30
# LUAD 28
# CESC 9
# PCPG 4
# THYM 0
# BLCA 16
# TGCT 2
# DLBC 2
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/488224173.py:2: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   print(d, non_wt_columns[non_wt_columns['SUBCLASS']== d]['gset'].apply(lambda x: 'AHNAK' in x if isinstance(x, list) else False).agg(sum))

# %%
total_gset = dict()
for d in data.SUBCLASS.unique():
    total_gset[d] = set()
    print(non_wt_columns[non_wt_columns['SUBCLASS']== d]['gset'].apply(lambda x : total_gset[d].update(set(x))))

# %%
cg_interset_dic = dict()

# %%
for d in data.SUBCLASS.unique():
    #print(d,len(total_gset[d]))
    inters = set(total_gset[d]).intersection( set(cgs['c.genes'].values))
    print(d, len(inters), len(total_gset[d]), len(inters)/len(total_gset[d]))
    cg_interset_dic[d] = inters
# Out:
# KIPAN 306 3007 0.101762554040572
# SARC 170 1546 0.10996119016817593
# SKCM 351 3933 0.08924485125858124
# KIRC 246 2214 0.1111111111111111
# GBMLGG 252 2300 0.10956521739130434
# STES 353 4024 0.08772365805168986
# BRCA 327 3486 0.09380378657487091
# THCA 115 907 0.12679162072767364
# LIHC 250 2393 0.10447137484329294
# HNSC 297 3059 0.09709055246812684
# PAAD 273 2740 0.09963503649635036
# OV 222 1957 0.11343893714869699
# PRAD 164 1393 0.11773151471643933
# UCEC 351 4002 0.08770614692653673
# LAML 60 316 0.189873417721519
# COAD 335 3660 0.09153005464480875
# ACC 179 1580 0.11329113924050632
# LGG 148 1111 0.1332133213321332
# LUSC 322 3329 0.09672574346650646
# LUAD 322 3122 0.1031390134529148
# CESC 341 2904 0.11742424242424243
# PCPG 69 523 0.13193116634799235
# THYM 66 388 0.17010309278350516
# BLCA 300 2930 0.10238907849829351
# TGCT 167 1365 0.12234432234432234
# DLBC 202 1656 0.12198067632850242

# %%
for d in data.SUBCLASS.unique():
    print(d,len(cg_interset_dic['DLBC'].intersection(cg_interset_dic[d])))
# Out:
# KIPAN 178
# SARC 104
# SKCM 200
# KIRC 151
# GBMLGG 159
# STES 199
# BRCA 193
# THCA 70
# LIHC 142
# HNSC 178
# PAAD 171
# OV 133
# PRAD 102
# UCEC 199
# LAML 38
# COAD 190
# ACC 110
# LGG 100
# LUSC 190
# LUAD 188
# CESC 192
# PCPG 48
# THYM 46
# BLCA 180
# TGCT 110
# DLBC 202

# %%
non_wt_columns[non_wt_columns['SUBCLASS']=='COAD']['gset'].apply(lambda x: 'AHNAK' in x if isinstance(x, list) else False).agg(sum)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/3121562874.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   non_wt_columns[non_wt_columns['SUBCLASS']=='COAD']['gset'].apply(lambda x: 'AHNAK' in x if isinstance(x, list) else False).agg(sum)
# 18

# %%
non_wt_columns['gset'].apply(lambda x: 'HLA-A' in x if isinstance(x, list) else False).agg(sum)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/1000975693.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   non_wt_columns['gset'].apply(lambda x: 'HLA-A' in x if isinstance(x, list) else False).agg(sum)
# 94

# %%
non_wt_columns_test = pd.DataFrame()
non_wt_columns_test['gset'] = df_test.iloc[:,2:].apply(get_non_wt_columns, axis=1).reset_index(name='gset').drop('index',axis=1)

# %%
non_wt_columns_test['gset'].apply(lambda x: 'AHNAK' in x if isinstance(x, list) else False).agg(sum)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/844878331.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   non_wt_columns_test['gset'].apply(lambda x: 'AHNAK' in x if isinstance(x, list) else False).agg(sum)
# 774

# %%
non_wt_columns_test['gset'].apply(lambda x: 'HLA-A' in x if isinstance(x, list) else False).agg(sum)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/1837752818.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   non_wt_columns_test['gset'].apply(lambda x: 'HLA-A' in x if isinstance(x, list) else False).agg(sum)
# 322

# %%
inters = set(data.columns).intersection( set(cgs['c.genes'].values))
len(inters)
# Out:
# 368

# %%
df_test['TP53'].apply(lambda x : x!='WT').agg(sum)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/278796587.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df_test['TP53'].apply(lambda x : x!='WT').agg(sum)
# 1051

# %%
data['TP53'].apply(lambda x : x!='WT').agg(sum)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/1942921877.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   data['TP53'].apply(lambda x : x!='WT').agg(sum)
# 1770

# %%
df_test['APC'].apply(lambda x : x!='WT').agg(sum)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/3030949284.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df_test['APC'].apply(lambda x : x!='WT').agg(sum)
# 706

# %%
data['APC'].apply(lambda x : x!='WT').agg(sum)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/3199270877.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   data['APC'].apply(lambda x : x!='WT').agg(sum)
# 367

# %%
data['AHNAK'].apply(lambda x : x!='WT').agg(sum)
# Out:
# /var/folders/91/x1jkjm3549s21y3h3k_k56q80000gn/T/ipykernel_44913/3891880499.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   data['AHNAK'].apply(lambda x : x!='WT').agg(sum)
# 349
