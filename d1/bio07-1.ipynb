# %%
import xgboost as xgb 
from xgboost import XGBClassifier, plot_importance
from sklearn.model_selection import train_test_split
import warnings
import pandas as pd
warnings.filterwarnings('ignore')

df = pd.read_csv('train.csv')
df.sort_values(by=['SUBCLASS'], inplace=True)
df_test = pd.read_csv('test.csv')
df_target = df['SUBCLASS']

data = df.drop(columns=['ID', 'SUBCLASS'])
df_test.drop(columns=['ID'], inplace=True)
data
# Out:
#      A2M AAAS AADAT AARS1 ABAT ABCA1   ABCA2 ABCA3 ABCA4   ABCA5  ... ZNF292  \
# 2112  WT   WT    WT    WT   WT    WT      WT    WT    WT      WT  ...     WT
# 2920  WT   WT    WT    WT   WT    WT      WT    WT    WT      WT  ...     WT
# 3101  WT   WT    WT    WT   WT    WT      WT    WT    WT      WT  ...     WT
# 4576  WT   WT    WT    WT   WT    WT      WT    WT    WT      WT  ...     WT
# 890   WT   WT    WT    WT   WT    WT      WT    WT    WT      WT  ...     WT
# ...   ..  ...   ...   ...  ...   ...     ...   ...   ...     ...  ...    ...
# 965   WT   WT    WT    WT   WT    WT  P1043P    WT    WT      WT  ...     WT
# 5809  WT   WT    WT    WT   WT    WT      WT    WT    WT      WT  ...     WT
# 3155  WT   WT    WT    WT   WT    WT      WT    WT    WT      WT  ...     WT
# 5833  WT   WT    WT    WT   WT    WT      WT    WT    WT      WT  ...     WT
# 5548  WT   WT    WT    WT   WT    WT      WT    WT    WT  D1199G  ...     WT
#
#      ZNF365 ZNF639 ZNF707 ZNFX1 ZNRF4 ZPBP  ZW10 ZWINT ZYX
# 2112     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 2920     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 3101     WT     WT     WT    WT  R36H   WT    WT    WT  WT
# 4576     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 890      WT     WT     WT    WT    WT   WT  Q98H    WT  WT
# ...     ...    ...    ...   ...   ...  ...   ...   ...  ..
# 965      WT     WT     WT    WT    WT   WT    WT    WT  WT
# 5809     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 3155     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 5833     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 5548     WT     WT     WT    WT    WT   WT    WT    WT  WT
#
# [6201 rows x 4384 columns]

# %%
disease_list = df.SUBCLASS.unique()
disease_list
# Out:
# array(['ACC', 'BLCA', 'BRCA', 'CESC', 'COAD', 'DLBC', 'GBMLGG', 'HNSC',
#        'KIPAN', 'KIRC', 'LAML', 'LGG', 'LIHC', 'LUAD', 'LUSC', 'OV',
#        'PAAD', 'PCPG', 'PRAD', 'SARC', 'SKCM', 'STES', 'TGCT', 'THCA',
#        'THYM', 'UCEC'], dtype=object)

# %%
df[df.SUBCLASS=='ACC']
# Out:
#               ID SUBCLASS A2M AAAS AADAT AARS1 ABAT ABCA1   ABCA2 ABCA3  ...  \
# 2112  TRAIN_2112      ACC  WT   WT    WT    WT   WT    WT      WT    WT  ...
# 2920  TRAIN_2920      ACC  WT   WT    WT    WT   WT    WT      WT    WT  ...
# 3101  TRAIN_3101      ACC  WT   WT    WT    WT   WT    WT      WT    WT  ...
# 4576  TRAIN_4576      ACC  WT   WT    WT    WT   WT    WT      WT    WT  ...
# 890   TRAIN_0890      ACC  WT   WT    WT    WT   WT    WT      WT    WT  ...
# ...          ...      ...  ..  ...   ...   ...  ...   ...     ...   ...  ...
# 1841  TRAIN_1841      ACC  WT   WT    WT    WT   WT    WT      WT    WT  ...
# 3930  TRAIN_3930      ACC  WT   WT    WT    WT   WT    WT      WT    WT  ...
# 2495  TRAIN_2495      ACC  WT   WT    WT    WT   WT    WT      WT    WT  ...
# 3259  TRAIN_3259      ACC  WT   WT    WT    WT   WT    WT      WT    WT  ...
# 767   TRAIN_0767      ACC  WT   WT    WT    WT   WT    WT  V1664G    WT  ...
#
#      ZNF292 ZNF365 ZNF639 ZNF707 ZNFX1 ZNRF4 ZPBP  ZW10 ZWINT ZYX
# 2112     WT     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 2920     WT     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 3101     WT     WT     WT     WT    WT  R36H   WT    WT    WT  WT
# 4576     WT     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 890      WT     WT     WT     WT    WT    WT   WT  Q98H    WT  WT
# ...     ...    ...    ...    ...   ...   ...  ...   ...   ...  ..
# 1841     WT     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 3930     WT     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 2495     WT     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 3259     WT     WT     WT     WT    WT    WT   WT    WT    WT  WT
# 767      WT     WT     WT     WT    WT    WT   WT    WT    WT  WT
#
# [72 rows x 4386 columns]

# %%
def seek1():
    count_df = df[df.SUBCLASS=='ACC'].apply(lambda x : x!='WT').agg(sum).reset_index(name='count')
    gene_list = count_df[count_df['count']>0]['index'].values
    print(len(gene_list))

# %%
df[df.SUBCLASS=='SKCM'].apply(lambda x : x!='WT').columns
# Out:
# Index(['ID', 'SUBCLASS', 'A2M', 'AAAS', 'AADAT', 'AARS1', 'ABAT', 'ABCA1',
#        'ABCA2', 'ABCA3',
#        ...
#        'ZNF292', 'ZNF365', 'ZNF639', 'ZNF707', 'ZNFX1', 'ZNRF4', 'ZPBP',
#        'ZW10', 'ZWINT', 'ZYX'],
#       dtype='object', length=4386)

# %%
def get_gene_list2():
    genes = []
    gene_set = set()
    for disease in df["SUBCLASS"].unique():
        disease_df = df[df["SUBCLASS"] == disease]

        non_wt_counts = (disease_df != 'WT').sum()  # "WT"가 아닌 행 개수
        non_wt_counts_sorted = non_wt_counts.sort_values(ascending=False) #빈도 수가 높은 순서대로 정렬

        n = 20 # 추출한 상위 유전자 개수
        genes.extend(list(non_wt_counts_sorted[2:2+n].index))

        #print(f'{disease} - 전체 행의 개수 : {len(disease_df)}')
        dd = non_wt_counts_sorted[2:n].reset_index()
        gene_list1 = dd['index'].values
        gene_set.update(gene_list1)
        #print(gene_list1)
    return gene_set

# %%
def get_gene_list1():
    selected_genes = set()
    for d in disease_list:
        count_df = df[df.SUBCLASS==d].apply(lambda x : x!='WT').agg(sum)
        count_df = count_df[2:].reset_index(name='count')        
        gene_list = count_df[count_df['count']>6]['index'].values
        print(d, len(gene_list))
        selected_genes.update(gene_list)
    print(len(selected_genes))
    return selected_genes
glist = get_gene_list1()
# Out:
# ACC 38
# BLCA 132
# BRCA 487
# CESC 121
# COAD 715
# DLBC 11
# GBMLGG 107
# HNSC 236
# KIPAN 194
# KIRC 38
# LAML 7
# LGG 12
# LIHC 65
# LUAD 358
# LUSC 434
# OV 29
# PAAD 15
# PCPG 3
# PRAD 11
# SARC 22
# SKCM 1844
# STES 1686
# TGCT 8
# THCA 3
# THYM 1
# UCEC 1633
# 2576

# %%
total = pd.concat([data, df_test])
total = total.loc[:, list(glist)]
total
# Out:
#                  ARHGAP29 SPDEF                                  DES KIF20A  \
# 2112                   WT    WT                                   WT     WT
# 2920                   WT    WT                                   WT     WT
# 3101                   WT    WT                                   WT     WT
# 4576                   WT    WT                                   WT     WT
# 890                    WT    WT                                   WT     WT
# ...                   ...   ...                                  ...    ...
# 2541                   WT    WT                                   WT     WT
# 2542                   WT    WT                                   WT     WT
# 2543  A998T A1062T A1053T    WT  Y315H Y398H Y405H Y382H Y261H Y404H     WT
# 2544                   WT    WT                                   WT     WT
# 2545                   WT    WT                                   WT     WT
#
#            COL6A3 U2AF1 SLC30A10 SMS   PAX3   GMPS  ...  \
# 2112           WT    WT       WT  WT     WT     WT  ...
# 2920           WT    WT       WT  WT     WT     WT  ...
# 3101           WT    WT       WT  WT     WT     WT  ...
# 4576           WT    WT       WT  WT     WT     WT  ...
# 890            WT    WT       WT  WT     WT     WT  ...
# ...           ...   ...      ...  ..    ...    ...  ...
# 2541           WT    WT       WT  WT     WT     WT  ...
# 2542           WT    WT       WT  WT     WT     WT  ...
# 2543  E138E E344E    WT       WT  WT   G81D  G606E  ...
# 2544           WT    WT       WT  WT  R270H     WT  ...
# 2545           WT    WT       WT  WT     WT     WT  ...
#
#                                         NEDD4 PRPF4B      ALDH3A1  POLG2  \
# 2112                                       WT     WT           WT     WT
# 2920                                       WT     WT           WT     WT
# 3101                                       WT     WT           WT     WT
# 4576                                       WT     WT           WT     WT
# 890                                        WT     WT           WT     WT
# ...                                       ...    ...          ...    ...
# 2541                                       WT     WT           WT     WT
# 2542                                       WT     WT           WT     WT
# 2543  T1112P T563P T1129P T1057P T710P T1113P  R440Q  R241C R314C  S178Y
# 2544                                       WT     WT           WT     WT
# 2545                                       WT     WT           WT     WT
#
#             RAD9A        ADCY1                  DMPK SLC6A3 DAPK2 KRT15
# 2112           WT           WT                    WT     WT    WT    WT
# 2920           WT           WT                    WT     WT    WT    WT
# 3101           WT           WT                    WT     WT    WT    WT
# 4576           WT           WT                    WT     WT    WT    WT
# 890            WT           WT                    WT     WT    WT    WT
# ...           ...          ...                   ...    ...   ...   ...
# 2541           WT           WT                    WT     WT    WT    WT
# 2542           WT           WT                    WT     WT    WT    WT
# 2543  Q256Q Q332Q  E296G E521G  G120G G5G G104G G94G     WT  R73W    WT
# 2544           WT           WT                    WT     WT    WT    WT
# 2545           WT           WT                    WT     WT    WT    WT
#
# [8747 rows x 2576 columns]

# %%
diseaseList = df.SUBCLASS.value_counts().rename_axis('disease').reset_index(name='counts')
diseaseList
# Out:
#    disease  counts
# 0     BRCA     786
# 1    KIPAN     515
# 2   GBMLGG     461
# 3     STES     379
# 4     KIRC     334
# 5     THCA     324
# 6     SKCM     276
# 7     PRAD     266
# 8       OV     253
# 9      LGG     229
# 10    HNSC     223
# 11    COAD     223
# 12    UCEC     198
# 13    SARC     198
# 14    LUAD     184
# 15    LUSC     178
# 16    LAML     158
# 17    LIHC     158
# 18    CESC     155
# 19    PCPG     147
# 20    TGCT     124
# 21    PAAD     120
# 22    BLCA     104
# 23    THYM      98
# 24     ACC      72
# 25    DLBC      38

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for c in total.columns:
    total[c] = encoder.fit_transform(total[c])

# %%
df = total[:6201]
df_test = total[6201:]

# %%
df
# Out:
#       ARHGAP29  SPDEF  DES  KIF20A  COL6A3  U2AF1  SLC30A10  SMS  PAX3  GMPS  \
# 2112       149     58   72      75     540     21        79   54   101    94
# 2920       149     58   72      75     540     21        79   54   101    94
# 3101       149     58   72      75     540     21        79   54   101    94
# 4576       149     58   72      75     540     21        79   54   101    94
# 890        149     58   72      75     540     21        79   54   101    94
# ...        ...    ...  ...     ...     ...    ...       ...  ...   ...   ...
# 965        149     58   72      75     540     21        79   54   101    94
# 5809       149     58   72      75     540     21        79   54   101    94
# 3155       149     58   72      75     540     21        79   54   101    94
# 5833       149     58   72      75     540     21        79   54   101    94
# 5548       149     58   72      75     540     21        79   54   101    94
#
#       ...  NEDD4  PRPF4B  ALDH3A1  POLG2  RAD9A  ADCY1  DMPK  SLC6A3  DAPK2  \
# 2112  ...    130     118       74     59     53    236    78     150     68
# 2920  ...    130     118       74     59     53    236    78     150     68
# 3101  ...    130     118       74     59     53    236    78     150     68
# 4576  ...    130     118       74     59     53    236    78     150     68
# 890   ...    130     118       74     59     53    236    78     150     68
# ...   ...    ...     ...      ...    ...    ...    ...   ...     ...    ...
# 965   ...    130     118       74     59     53    236    78     150     68
# 5809  ...    130     118       74     59     53    236    78     150     68
# 3155  ...    130     118       74     59     53    236    78     150     68
# 5833  ...    130     118       74     59     53    236    78     150     68
# 5548  ...    130     118       74     59     53    236    78     150     68
#
#       KRT15
# 2112     96
# 2920     96
# 3101     96
# 4576     96
# 890      96
# ...     ...
# 965      96
# 5809     96
# 3155     96
# 5833     96
# 5548     96
#
# [6201 rows x 2576 columns]

# %%
df_test
# Out:
#       ARHGAP29  SPDEF  DES  KIF20A  COL6A3  U2AF1  SLC30A10  SMS  PAX3  GMPS  \
# 0          149     58   72      75     540     21        79   54   101    94
# 1          149     58   72      44     540     21        79   54    33    94
# 2          149     58   72      75     540     21        79   54   101    94
# 3          149     58   72      75     540     21        79   54   101    94
# 4          149     58   72      75     540     21        79   54   101    94
# ...        ...    ...  ...     ...     ...    ...       ...  ...   ...   ...
# 2541       149     58   72      75     540     21        79   54   101    94
# 2542       149     58   72      75     540     21        79   54   101    94
# 2543         7     58   74      75     115     21        79   54    21    31
# 2544       149     58   72      75     540     21        79   54    63    94
# 2545       149     58   72      75     540     21        79   54   101    94
#
#       ...  NEDD4  PRPF4B  ALDH3A1  POLG2  RAD9A  ADCY1  DMPK  SLC6A3  DAPK2  \
# 0     ...    130     118       74     59     53    236    78     150     68
# 1     ...    130     118       74     59     53    236    78     150     68
# 2     ...    130     118       74     59     53    236    78     150     68
# 3     ...    130     118       74     59     53    236    78     150     68
# 4     ...    130     118       74     59     53    236    78     150     68
# ...   ...    ...     ...      ...    ...    ...    ...   ...     ...    ...
# 2541  ...    130     118       74     59     53    236    78     150     68
# 2542  ...    130     118       74     59     53    236    78     150     68
# 2543  ...    122      74       62     50     32     47    24     150     51
# 2544  ...    130     118       74     59     53    236    78     150     68
# 2545  ...    130     118       74     59     53    236    78     150     68
#
#       KRT15
# 0        96
# 1        96
# 2        96
# 3        96
# 4        96
# ...     ...
# 2541     96
# 2542     96
# 2543     96
# 2544     96
# 2545     96
#
# [2546 rows x 2576 columns]

# %%
from sklearn.preprocessing import LabelEncoder
X = df
y = df_target
encoder2 = LabelEncoder()
y = encoder2.fit_transform(y)
y
# Out:
# array([ 0,  0,  0, ..., 25, 25, 25])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, stratify = y, random_state=156)#shuffle=False,
print(X_train.shape, X_test.shape)
# Out:
# (4340, 2576) (1861, 2576)

# %%
dtrain = xgb.DMatrix(data = X_train, label= y_train)
dtest = xgb.DMatrix(data = X_test, label = y_test)

# %% [markdown]
# #Multi-class classification

# %%
params = {
    'tree_method': 'approx',
    'objective': 'multi:softprob',
    'num_class': 26
}
num_boost_round = 50

dtrain = xgb.DMatrix(data = X_train, label= y_train)
dtest = xgb.DMatrix(data = X_test, label = y_test)
model = xgb.train(params=params, dtrain=dtrain, num_boost_round=num_boost_round, #early_stopping_rounds=5, 
                  evals=[(dtrain, 'train'), (dtest, 'valid')],
                  verbose_eval=2)
# Out:
# [0]	train-mlogloss:2.61867	valid-mlogloss:2.72837
# [2]	train-mlogloss:2.22856	valid-mlogloss:2.47488
# [4]	train-mlogloss:1.99924	valid-mlogloss:2.34766
# [6]	train-mlogloss:1.84106	valid-mlogloss:2.27542
# [8]	train-mlogloss:1.72117	valid-mlogloss:2.22814
# [10]	train-mlogloss:1.62752	valid-mlogloss:2.19575
# [12]	train-mlogloss:1.55302	valid-mlogloss:2.17599
# [14]	train-mlogloss:1.49200	valid-mlogloss:2.15960
# [16]	train-mlogloss:1.43761	valid-mlogloss:2.14514
# [18]	train-mlogloss:1.39027	valid-mlogloss:2.14217
# [20]	train-mlogloss:1.34741	valid-mlogloss:2.13675
# [22]	train-mlogloss:1.30861	valid-mlogloss:2.13091
# [24]	train-mlogloss:1.27389	valid-mlogloss:2.12689
# [26]	train-mlogloss:1.24288	valid-mlogloss:2.12460
# [28]	train-mlogloss:1.21496	valid-mlogloss:2.12357
# [30]	train-mlogloss:1.18859	valid-mlogloss:2.12136
# [32]	train-mlogloss:1.16461	valid-mlogloss:2.11868
# [34]	train-mlogloss:1.14028	valid-mlogloss:2.11837
# [36]	train-mlogloss:1.11888	valid-mlogloss:2.12054
# [38]	train-mlogloss:1.09800	valid-mlogloss:2.12126
# [40]	train-mlogloss:1.07824	valid-mlogloss:2.12252
# [42]	train-mlogloss:1.05989	valid-mlogloss:2.12387
# [44]	train-mlogloss:1.04232	valid-mlogloss:2.12574
# [46]	train-mlogloss:1.02506	valid-mlogloss:2.12663
# [48]	train-mlogloss:1.00900	valid-mlogloss:2.12760
# [49]	train-mlogloss:1.00044	valid-mlogloss:2.12821

# %%
params = {
    'tree_method': 'approx',
    'objective': 'multi:softprob',
    'learning_rate': 0.05
}
num_boost_round = 200
clf = xgb.XGBClassifier(n_estimators=num_boost_round,early_stopping_rounds=5, **params)
clf.fit(X_train, y_train, 
        eval_set=[(X_train, y_train), (X_test,y_test)],
        verbose=2);
# Out:
# [0]	validation_0-mlogloss:3.13960	validation_1-mlogloss:3.15795
# [2]	validation_0-mlogloss:2.96146	validation_1-mlogloss:3.01474
# [4]	validation_0-mlogloss:2.82474	validation_1-mlogloss:2.90666
# [6]	validation_0-mlogloss:2.71345	validation_1-mlogloss:2.82152
# [8]	validation_0-mlogloss:2.61922	validation_1-mlogloss:2.75040
# [10]	validation_0-mlogloss:2.53752	validation_1-mlogloss:2.69206
# [12]	validation_0-mlogloss:2.46604	validation_1-mlogloss:2.64276
# [14]	validation_0-mlogloss:2.40100	validation_1-mlogloss:2.59830
# [16]	validation_0-mlogloss:2.34289	validation_1-mlogloss:2.55939
# [18]	validation_0-mlogloss:2.28988	validation_1-mlogloss:2.52477
# [20]	validation_0-mlogloss:2.24107	validation_1-mlogloss:2.49443
# [22]	validation_0-mlogloss:2.19606	validation_1-mlogloss:2.46677
# [24]	validation_0-mlogloss:2.15364	validation_1-mlogloss:2.44101
# [26]	validation_0-mlogloss:2.11428	validation_1-mlogloss:2.41768
# [28]	validation_0-mlogloss:2.07726	validation_1-mlogloss:2.39808
# [30]	validation_0-mlogloss:2.04257	validation_1-mlogloss:2.37972
# [32]	validation_0-mlogloss:2.01022	validation_1-mlogloss:2.36209
# [34]	validation_0-mlogloss:1.97943	validation_1-mlogloss:2.34559
# [36]	validation_0-mlogloss:1.95051	validation_1-mlogloss:2.33105
# [38]	validation_0-mlogloss:1.92339	validation_1-mlogloss:2.31740
# [40]	validation_0-mlogloss:1.89791	validation_1-mlogloss:2.30469
# [42]	validation_0-mlogloss:1.87331	validation_1-mlogloss:2.29292
# [44]	validation_0-mlogloss:1.84971	validation_1-mlogloss:2.28181
# [46]	validation_0-mlogloss:1.82712	validation_1-mlogloss:2.27195
# [48]	validation_0-mlogloss:1.80554	validation_1-mlogloss:2.26174
# [50]	validation_0-mlogloss:1.78492	validation_1-mlogloss:2.25251
# [52]	validation_0-mlogloss:1.76552	validation_1-mlogloss:2.24343
# [54]	validation_0-mlogloss:1.74646	validation_1-mlogloss:2.23534
# [56]	validation_0-mlogloss:1.72790	validation_1-mlogloss:2.22816
# [58]	validation_0-mlogloss:1.71042	validation_1-mlogloss:2.22092
# [60]	validation_0-mlogloss:1.69311	validation_1-mlogloss:2.21391
# [62]	validation_0-mlogloss:1.67696	validation_1-mlogloss:2.20793
# [64]	validation_0-mlogloss:1.66134	validation_1-mlogloss:2.20240
# [66]	validation_0-mlogloss:1.64675	validation_1-mlogloss:2.19688
# [68]	validation_0-mlogloss:1.63259	validation_1-mlogloss:2.19106
# [70]	validation_0-mlogloss:1.61866	validation_1-mlogloss:2.18638
# [72]	validation_0-mlogloss:1.60497	validation_1-mlogloss:2.18150
# [74]	validation_0-mlogloss:1.59253	validation_1-mlogloss:2.17770
# [76]	validation_0-mlogloss:1.58000	validation_1-mlogloss:2.17359
# [78]	validation_0-mlogloss:1.56805	validation_1-mlogloss:2.16964
# [80]	validation_0-mlogloss:1.55663	validation_1-mlogloss:2.16617
# [82]	validation_0-mlogloss:1.54522	validation_1-mlogloss:2.16378
# [84]	validation_0-mlogloss:1.53432	validation_1-mlogloss:2.16030
# [86]	validation_0-mlogloss:1.52349	validation_1-mlogloss:2.15743
# [88]	validation_0-mlogloss:1.51334	validation_1-mlogloss:2.15464
# [90]	validation_0-mlogloss:1.50314	validation_1-mlogloss:2.15220
# [92]	validation_0-mlogloss:1.49340	validation_1-mlogloss:2.15024
# [94]	validation_0-mlogloss:1.48374	validation_1-mlogloss:2.14817
# [96]	validation_0-mlogloss:1.47471	validation_1-mlogloss:2.14661
# [98]	validation_0-mlogloss:1.46575	validation_1-mlogloss:2.14425
# [100]	validation_0-mlogloss:1.45709	validation_1-mlogloss:2.14227
# [102]	validation_0-mlogloss:1.44832	validation_1-mlogloss:2.14055
# [104]	validation_0-mlogloss:1.44007	validation_1-mlogloss:2.13850
# [106]	validation_0-mlogloss:1.43193	validation_1-mlogloss:2.13700
# [108]	validation_0-mlogloss:1.42387	validation_1-mlogloss:2.13543
# [110]	validation_0-mlogloss:1.41572	validation_1-mlogloss:2.13436
# [112]	validation_0-mlogloss:1.40792	validation_1-mlogloss:2.13287
# [114]	validation_0-mlogloss:1.40048	validation_1-mlogloss:2.13137
# [116]	validation_0-mlogloss:1.39302	validation_1-mlogloss:2.13019
# [118]	validation_0-mlogloss:1.38604	validation_1-mlogloss:2.12857
# [120]	validation_0-mlogloss:1.37909	validation_1-mlogloss:2.12721
# [122]	validation_0-mlogloss:1.37231	validation_1-mlogloss:2.12600
# [124]	validation_0-mlogloss:1.36565	validation_1-mlogloss:2.12513
# [126]	validation_0-mlogloss:1.35914	validation_1-mlogloss:2.12427
# [128]	validation_0-mlogloss:1.35258	validation_1-mlogloss:2.12327
# [130]	validation_0-mlogloss:1.34607	validation_1-mlogloss:2.12257
# [132]	validation_0-mlogloss:1.34007	validation_1-mlogloss:2.12160
# [134]	validation_0-mlogloss:1.33384	validation_1-mlogloss:2.12070
# [136]	validation_0-mlogloss:1.32782	validation_1-mlogloss:2.11968
# [138]	validation_0-mlogloss:1.32193	validation_1-mlogloss:2.11852
# [140]	validation_0-mlogloss:1.31608	validation_1-mlogloss:2.11773
# [142]	validation_0-mlogloss:1.31028	validation_1-mlogloss:2.11722
# [144]	validation_0-mlogloss:1.30468	validation_1-mlogloss:2.11681
# [146]	validation_0-mlogloss:1.29919	validation_1-mlogloss:2.11618
# [148]	validation_0-mlogloss:1.29383	validation_1-mlogloss:2.11557
# [150]	validation_0-mlogloss:1.28854	validation_1-mlogloss:2.11474
# [152]	validation_0-mlogloss:1.28322	validation_1-mlogloss:2.11460
# [154]	validation_0-mlogloss:1.27806	validation_1-mlogloss:2.11426
# [156]	validation_0-mlogloss:1.27290	validation_1-mlogloss:2.11408
# [158]	validation_0-mlogloss:1.26773	validation_1-mlogloss:2.11383
# [160]	validation_0-mlogloss:1.26258	validation_1-mlogloss:2.11322
# [162]	validation_0-mlogloss:1.25757	validation_1-mlogloss:2.11255
# [164]	validation_0-mlogloss:1.25240	validation_1-mlogloss:2.11209
# [166]	validation_0-mlogloss:1.24760	validation_1-mlogloss:2.11184
# [168]	validation_0-mlogloss:1.24284	validation_1-mlogloss:2.11158
# [170]	validation_0-mlogloss:1.23780	validation_1-mlogloss:2.11126
# [172]	validation_0-mlogloss:1.23293	validation_1-mlogloss:2.11119
# [174]	validation_0-mlogloss:1.22812	validation_1-mlogloss:2.11121
# [176]	validation_0-mlogloss:1.22349	validation_1-mlogloss:2.11110
# [178]	validation_0-mlogloss:1.21884	validation_1-mlogloss:2.11090
# [180]	validation_0-mlogloss:1.21433	validation_1-mlogloss:2.11101
# [182]	validation_0-mlogloss:1.21003	validation_1-mlogloss:2.11056
# [184]	validation_0-mlogloss:1.20571	validation_1-mlogloss:2.11011
# [186]	validation_0-mlogloss:1.20160	validation_1-mlogloss:2.10983
# [188]	validation_0-mlogloss:1.19745	validation_1-mlogloss:2.10965
# [190]	validation_0-mlogloss:1.19329	validation_1-mlogloss:2.10961
# [192]	validation_0-mlogloss:1.18917	validation_1-mlogloss:2.10920
# [194]	validation_0-mlogloss:1.18497	validation_1-mlogloss:2.10933
# [196]	validation_0-mlogloss:1.18083	validation_1-mlogloss:2.10894
# [198]	validation_0-mlogloss:1.17675	validation_1-mlogloss:2.10849
# [199]	validation_0-mlogloss:1.17477	validation_1-mlogloss:2.10848

# %%
y_true = y_test
y_pred = clf.predict(X_test)
y_score = clf.predict_proba(X_test)
y_true.shape, y_pred.shape, y_score.shape
# Out:
# ((1861,), (1861,), (1861, 26))

# %%
from sklearn import metrics 
metrics.accuracy_score(y_true, y_pred)
# Out:
# 0.34390112842557763

# %%
from sklearn import metrics 
metrics.accuracy_score(y_true, y_pred)
# Out:
# 0.34390112842557763

# %%
print(metrics.classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.68      0.77        22
#            1       0.43      0.19      0.27        31
#            2       0.30      0.69      0.42       236
#            3       0.00      0.00      0.00        47
#            4       0.63      0.54      0.58        67
#            5       1.00      0.27      0.43        11
#            6       0.29      0.30      0.29       138
#            7       0.29      0.24      0.26        67
#            8       0.21      0.24      0.22       155
#            9       0.12      0.07      0.09       100
#           10       0.70      0.49      0.57        47
#           11       0.27      0.28      0.27        69
#           12       0.29      0.26      0.27        47
#           13       0.32      0.11      0.16        55
#           14       0.17      0.08      0.11        53
#           15       0.24      0.42      0.31        76
#           16       0.25      0.08      0.12        36
#           17       0.14      0.09      0.11        44
#           18       0.29      0.16      0.21        80
#           19       0.21      0.10      0.13        60
#           20       0.71      0.63      0.67        83
#           21       0.34      0.32      0.33       114
#           22       0.46      0.30      0.36        37
#           23       0.70      0.59      0.64        97
#           24       0.60      0.10      0.18        29
#           25       0.65      0.58      0.61        60
#
#     accuracy                           0.34      1861
#    macro avg       0.40      0.30      0.32      1861
# weighted avg       0.35      0.34      0.33      1861

# %%
metrics.roc_auc_score(y_true, y_score, average='weighted', multi_class='ovr')
# Out:
# 0.8550985140255167

# %%
clf.predict(df_test)
# Out:
# array([21, 25, 23, ..., 20, 10, 11])

# %%
res = clf.predict(df_test)

# %%
res = encoder2.inverse_transform(res)

# %%
df_test1 = pd.read_csv('test.csv')
res_df = pd.DataFrame ({'ID' : df_test1['ID'], 'SUBCLASS' : res})
res_df
# Out:
#              ID SUBCLASS
# 0     TEST_0000     STES
# 1     TEST_0001     UCEC
# 2     TEST_0002     THCA
# 3     TEST_0003      LGG
# 4     TEST_0004     HNSC
# ...         ...      ...
# 2541  TEST_2541     BLCA
# 2542  TEST_2542     HNSC
# 2543  TEST_2543     SKCM
# 2544  TEST_2544     LAML
# 2545  TEST_2545      LGG
#
# [2546 rows x 2 columns]

# %%
res_df.to_csv('res07-2578-6-2.csv',index = False)

# %%
pred_probs = xgb_model.predict(dtest)

# %%
import numpy as np
print(np.round(pred_probs[:10], 3))

# %%
preds= [round(x) if x > 0 else 0 for x in pred_probs]

# %%
preds

# %%
for p in preds:
    if p<0:
        print(p)

# %%
encoder.inverse_transform(preds)

# %%
model = RandomForestClassifier(
            n_estimators=50, ## 붓스트랩 샘플 개수 또는 base_estimator 개수
            criterion='entropy', ## 불순도 측도
            max_depth=65, ## 개별 나무의 최대 깊이
            #max_features='sqrt', ## 매 분리시 랜덤으로 뽑을 변수 개수
            #max_samples=1.0, ## 붓스트랩 샘플 비율 => 1이면 학습데이터를 모두 샘플링한다.
            #bootstrap=True, ## 복원 추출,  False이면 비복원 추출
            oob_score=True, ## Out-of-bag 데이터를 이용한 성능 계산
            random_state=100
).fit(X,y)

# %%
## 예측
print(model.predict(X)[:3]) 
print()

# %%
X[:3]

# %%
## 성능 평가
print(model.oob_score_) ## Out-of-bag 성능 평가 점수
print('정확도 : ', model.score(X,y)) ## 테스트 성능 평가 점수(Accuracy)
print()
## 변수 중요도
print(model.feature_importances_)

# %%
## 성능 평가
print(model.oob_score_) ## Out-of-bag 성능 평가 점수
print('정확도 : ', model.score(X,y)) ## 테스트 성능 평가 점수(Accuracy)
print()
## 변수 중요도
print(model.feature_importances_)

# %%
res = model.predict(df_test)
res

# %%
res = model.predict(df_test)
res

# %%
df_test1 = pd.read_csv('test.csv')
res_df = pd.DataFrame ({'ID' : df_test1['ID'], 'SUBCLASS' : res})
res_df

# %%
res_df.to_csv('res04.csv',index = False)

# %%
df[df.SUBCLASS == 'BRCA'].sum().sort_values(ascending=False).str.replace('WT','')

# %%
df[df['SUBCLASS']=='DLBC']

# %%
import numpy as np 
dfs = df[df['SUBCLASS']=='DLBC']
dfs.columns

# %%
for c in dfs.columns:
    dfs[c] = np.where(dfs[c] == 'WT', 0, 1)
dfs

# %%
dfs = df[df['SUBCLASS']=='DLBC']
dfs.apply(lambda x: x(if x=='WT' else x=1))

# %%
for  x in df.iloc[0]:
    if x != 'WT': print(x)

# %%
len(df_test.columns)

# %%
len(df_test)

# %%
df.colu
