# %%
import xgboost as xgb 
from xgboost import XGBClassifier, plot_importance
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd 
df = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
df_target = df['SUBCLASS']

data = df.drop(columns=['ID', 'SUBCLASS'])
df_test.drop(columns=['ID'], inplace=True)
data
# Out:
#         A2M AAAS AADAT AARS1 ABAT ABCA1 ABCA2 ABCA3 ABCA4 ABCA5  ... ZNF292  \
# 0        WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 1        WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 2     R895R   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 3        WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 4        WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# ...     ...  ...   ...   ...  ...   ...   ...   ...   ...   ...  ...    ...
# 6196     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 6197     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 6198     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 6199     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
# 6200     WT   WT    WT    WT   WT    WT    WT    WT    WT    WT  ...     WT
#
#      ZNF365 ZNF639 ZNF707 ZNFX1 ZNRF4 ZPBP ZW10  ZWINT ZYX
# 0        WT     WT     WT    WT    WT   WT   WT     WT  WT
# 1        WT     WT     WT    WT    WT   WT   WT     WT  WT
# 2        WT     WT     WT    WT    WT   WT   WT     WT  WT
# 3        WT     WT     WT    WT    WT   WT   WT     WT  WT
# 4        WT     WT     WT    WT    WT   WT   WT     WT  WT
# ...     ...    ...    ...   ...   ...  ...  ...    ...  ..
# 6196     WT     WT     WT    WT    WT   WT   WT     WT  WT
# 6197     WT     WT     WT    WT    WT   WT   WT     WT  WT
# 6198     WT     WT     WT    WT    WT   WT   WT  T181S  WT
# 6199     WT     WT     WT    WT    WT   WT   WT     WT  WT
# 6200     WT     WT     WT    WT    WT   WT   WT     WT  WT
#
# [6201 rows x 4384 columns]

# %%
disease_list = df.SUBCLASS.unique()
disease_list
# Out:
# array(['KIPAN', 'SARC', 'SKCM', 'KIRC', 'GBMLGG', 'STES', 'BRCA', 'THCA',
#        'LIHC', 'HNSC', 'PAAD', 'OV', 'PRAD', 'UCEC', 'LAML', 'COAD',
#        'ACC', 'LGG', 'LUSC', 'LUAD', 'CESC', 'PCPG', 'THYM', 'BLCA',
#        'TGCT', 'DLBC'], dtype=object)

# %%
df[df.SUBCLASS=='ACC']
# Out:
#               ID SUBCLASS A2M AAAS AADAT AARS1 ABAT   ABCA1 ABCA2 ABCA3  ...  \
# 30    TRAIN_0030      ACC  WT   WT    WT    WT   WT      WT    WT    WT  ...
# 44    TRAIN_0044      ACC  WT   WT    WT    WT   WT      WT    WT    WT  ...
# 50    TRAIN_0050      ACC  WT   WT    WT    WT   WT      WT    WT    WT  ...
# 183   TRAIN_0183      ACC  WT   WT    WT    WT   WT      WT    WT    WT  ...
# 656   TRAIN_0656      ACC  WT   WT    WT    WT   WT      WT    WT    WT  ...
# ...          ...      ...  ..  ...   ...   ...  ...     ...   ...   ...  ...
# 5901  TRAIN_5901      ACC  WT   WT    WT    WT   WT      WT    WT    WT  ...
# 5917  TRAIN_5917      ACC  WT   WT    WT    WT   WT      WT    WT    WT  ...
# 6035  TRAIN_6035      ACC  WT   WT    WT    WT   WT      WT    WT    WT  ...
# 6082  TRAIN_6082      ACC  WT   WT    WT    WT   WT      WT    WT    WT  ...
# 6148  TRAIN_6148      ACC  WT   WT    WT    WT   WT  P1428P    WT    WT  ...
#
#      ZNF292 ZNF365 ZNF639 ZNF707 ZNFX1 ZNRF4 ZPBP ZW10 ZWINT ZYX
# 30       WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
# 44       WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
# 50       WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
# 183      WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
# 656      WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
# ...     ...    ...    ...    ...   ...   ...  ...  ...   ...  ..
# 5901     WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
# 5917     WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
# 6035     WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
# 6082     WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
# 6148     WT     WT     WT     WT    WT    WT   WT   WT    WT  WT
#
# [72 rows x 4386 columns]

# %%
count_df = df[df.SUBCLASS=='ACC'].apply(lambda x : x!='WT').agg(sum).reset_index(name='count')
gene_list = count_df[count_df['count']>0]['index'].values
print(len(gene_list))
# Out:
# 1582

# %%
df[df.SUBCLASS=='SKCM'].apply(lambda x : x!='WT').columns
# Out:
# Index(['ID', 'SUBCLASS', 'A2M', 'AAAS', 'AADAT', 'AARS1', 'ABAT', 'ABCA1',
#        'ABCA2', 'ABCA3',
#        ...
#        'ZNF292', 'ZNF365', 'ZNF639', 'ZNF707', 'ZNFX1', 'ZNRF4', 'ZPBP',
#        'ZW10', 'ZWINT', 'ZYX'],
#       dtype='object', length=4386)

# %%
selected_genes = set()
for d in disease_list:
    print(d)
    count_df = df[df.SUBCLASS==d].apply(lambda x : x!='WT').agg(sum).reset_index(name='count')
    gene_list = count_df[count_df['count']>0]['index'].values
    print(len(gene_list))
    selected_genes = selected_genes.union(gene_list)
# Out:
# KIPAN
# 3010
# SARC
# 1549
# SKCM
# 3936
# KIRC
# 2217
# GBMLGG
# 2303
# STES
# 4027
# BRCA
# 3489
# THCA
# 909
# LIHC
# 2396
# HNSC
# 3062
# PAAD
# 2743
# OV
# 1960
# PRAD
# 1395
# UCEC
# 4005
# LAML
# 318
# COAD
# 3663
# ACC
# 1582
# LGG
# 1114
# LUSC
# 3332
# LUAD
# 3125
# CESC
# 2907
# PCPG
# 526
# THYM
# 390
# BLCA
# 2933
# TGCT
# 1368
# DLBC
# 1659

# %%
genes = []
gene_set = set()
for disease in df["SUBCLASS"].unique():
    disease_df = df[df["SUBCLASS"] == disease]

    non_wt_counts = (disease_df != 'WT').sum()  # "WT"가 아닌 행 개수
    non_wt_counts_sorted = non_wt_counts.sort_values(ascending=False) #빈도 수가 높은 순서대로 정렬

    n = 20 # 추출한 상위 유전자 개수
    genes.extend(list(non_wt_counts_sorted[2:2+n].index))

    #print(f'{disease} - 전체 행의 개수 : {len(disease_df)}')
    dd = non_wt_counts_sorted[2:n].reset_index()
    gene_list1 = dd['index'].values
    gene_set.update(gene_list1)
    #print(gene_list1)
gene_set
# Out:
# {'ABCA3',
#  'ACACA',
#  'ADCY2',
#  'AGRN',
#  'AHNAK',
#  'AKAP13',
#  'ALB',
#  'ALMS1',
#  'AMOT',
#  'ANK1',
#  'APC',
#  'AQP7',
#  'ARHGAP5',
#  'ARID5B',
#  'ATRX',
#  'AXIN1',
#  'AXL',
#  'B2M',
#  'BCL6',
#  'BMP2K',
#  'BRAF',
#  'BRCA1',
#  'BTG1',
#  'BTG2',
#  'CACNA1A',
#  'CACNA1B',
#  'CACNA1H',
#  'CDC27',
#  'CDH1',
#  'CDH8',
#  'CDKN1A',
#  'CDKN2A',
#  'CEBPA',
#  'CELSR1',
#  'CHEK2',
#  'CKB',
#  'CLIP1',
#  'CLIP2',
#  'CMPK2',
#  'COL11A1',
#  'COL12A1',
#  'COL17A1',
#  'COL4A1',
#  'COL5A1',
#  'COL5A2',
#  'COL5A3',
#  'COL6A3',
#  'CREBBP',
#  'CROCC',
#  'CTCF',
#  'CTNNB1',
#  'CYLD',
#  'DCC',
#  'DLC1',
#  'DMD',
#  'DOCK2',
#  'DST',
#  'DYNC1H1',
#  'EGFR',
#  'ENPP2',
#  'ERBB3',
#  'ERCC2',
#  'FASN',
#  'FBN1',
#  'FBN2',
#  'FBXW7',
#  'FGFR3',
#  'GATA3',
#  'GBP4',
#  'GJB3',
#  'GNAS',
#  'GYS1',
#  'HELZ2',
#  'HLA-C',
#  'HMGB3',
#  'HRAS',
#  'HSPA8',
#  'HUWE1',
#  'IDH1',
#  'IDH2',
#  'IDUA',
#  'IFITM3',
#  'IRF4',
#  'IRS2',
#  'KALRN',
#  'KIF3B',
#  'KIT',
#  'KMT2D',
#  'KNTC1',
#  'LAMA1',
#  'LAMA2',
#  'LAMA3',
#  'LAMA4',
#  'LRIG1',
#  'LRP1',
#  'MAML2',
#  'MAP1B',
#  'MAP3K1',
#  'MEFV',
#  'MET',
#  'MFHAS1',
#  'MKI67',
#  'MTOR',
#  'MXRA5',
#  'MYH1',
#  'MYH2',
#  'MYH4',
#  'MYH7',
#  'MYH8',
#  'MYH9',
#  'MYLK',
#  'NCOA6',
#  'NCOR2',
#  'NEFH',
#  'NF1',
#  'NFE2L2',
#  'NFKB2',
#  'NLRP3',
#  'NOS1',
#  'NOTCH1',
#  'NOTCH2',
#  'NOTCH3',
#  'NPM1',
#  'OGFR',
#  'PABPC1',
#  'PCDH7',
#  'PCLO',
#  'PCSK1',
#  'PDE4DIP',
#  'PEG3',
#  'PEX6',
#  'PGLS',
#  'PHLDB1',
#  'PIK3CA',
#  'PIM1',
#  'PKD1',
#  'PKHD1',
#  'PLCB4',
#  'PLEC',
#  'PLXNB2',
#  'PPM1D',
#  'PRKDC',
#  'PTEN',
#  'PTGIR',
#  'PTPN11',
#  'PTPRD',
#  'RAD21',
#  'RB1',
#  'RELN',
#  'RET',
#  'RNF213',
#  'RREB1',
#  'RUNX1',
#  'RYR1',
#  'RYR2',
#  'SCN10A',
#  'SLC12A4',
#  'SMC1A',
#  'SMC3',
#  'SOWAHC',
#  'SPOP',
#  'SPTA1',
#  'SPTAN1',
#  'SPTBN1',
#  'SRD5A1',
#  'STAB1',
#  'STC2',
#  'SYMPK',
#  'SYNE1',
#  'TATDN2',
#  'TCHH',
#  'TCIRG1',
#  'TENM2',
#  'TG',
#  'TGFBR2',
#  'THEM4',
#  'TM7SF2',
#  'TNC',
#  'TNFAIP3',
#  'TP53',
#  'TRA2B',
#  'U2AF1',
#  'VCAN',
#  'VHL',
#  'VWF',
#  'ZFPM2'}

# %%
df_test
# Out:
#      A2M AAAS AADAT AARS1 ABAT  ABCA1        ABCA2 ABCA3   ABCA4    ABCA5  \
# 0     WT   WT    WT    WT   WT     WT           WT    WT      WT       WT
# 1     WT   WT    WT    WT   WT  R587Q           WT    WT      WT       WT
# 2     WT   WT    WT    WT   WT     WT           WT    WT      WT       WT
# 3     WT   WT    WT    WT   WT     WT           WT    WT      WT       WT
# 4     WT   WT    WT    WT   WT     WT           WT    WT      WT       WT
# ...   ..  ...   ...   ...  ...    ...          ...   ...     ...      ...
# 2541  WT   WT    WT    WT   WT     WT           WT    WT      WT       WT
# 2542  WT   WT    WT    WT   WT     WT           WT    WT      WT       WT
# 2543  WT   WT    WT    WT   WT  L217I  P221P P251P   R5M   G606D  I248Nfs
# 2544  WT   WT    WT    WT   WT     WT           WT    WT  R1517H       WT
# 2545  WT   WT    WT    WT   WT     WT           WT    WT      WT       WT
#
#       ...             ZNF292 ZNF365 ZNF639 ZNF707  ZNFX1    ZNRF4  \
# 0     ...                 WT     WT     WT     WT     WT       WT
# 1     ...                 WT     WT     WT     WT     WT  I383Sfs
# 2     ...                 WT     WT     WT     WT     WT       WT
# 3     ...                 WT     WT     WT     WT     WT       WT
# 4     ...                 WT     WT     WT     WT     WT       WT
# ...   ...                ...    ...    ...    ...    ...      ...
# 2541  ...                 WT     WT     WT     WT     WT       WT
# 2542  ...                 WT     WT     WT     WT     WT       WT
# 2543  ...  S2049Vfs S1909Vfs  L232R     WT     WT  L305L       WT
# 2544  ...                 WT     WT     WT     WT     WT       WT
# 2545  ...                 WT     WT     WT     WT     WT       WT
#
#              ZPBP   ZW10 ZWINT ZYX
# 0              WT     WT    WT  WT
# 1              WT     WT    WT  WT
# 2              WT     WT    WT  WT
# 3              WT     WT    WT  WT
# 4              WT     WT    WT  WT
# ...           ...    ...   ...  ..
# 2541           WT     WT    WT  WT
# 2542           WT     WT    WT  WT
# 2543  N252I N251I  G679V    WT  WT
# 2544           WT     WT    WT  WT
# 2545           WT     WT    WT  WT
#
# [2546 rows x 4384 columns]

# %%
len(gene_set)
# Out:
# 186

# %%
total = pd.concat([data, df_test])
total = total.loc[:, list(gene_set)]

# %%
total
# Out:
#      MEFV CKB               AKAP13  PCDH7        NCOR2 TNFAIP3 GYS1 SYMPK  \
# 0      WT  WT                   WT     WT           WT      WT   WT    WT
# 1      WT  WT                   WT     WT           WT      WT   WT    WT
# 2      WT  WT                   WT     WT           WT      WT   WT    WT
# 3      WT  WT                   WT     WT           WT      WT   WT    WT
# 4      WT  WT                   WT     WT           WT      WT   WT    WT
# ...   ...  ..                  ...    ...          ...     ...  ...   ...
# 2541   WT  WT                   WT     WT           WT      WT   WT    WT
# 2542   WT  WT                   WT     WT           WT      WT   WT    WT
# 2543   WT  WT  A1684A A302A A1680A  M977I  P760S P778S      WT   WT    WT
# 2544   WT  WT                   WT     WT           WT      WT   WT    WT
# 2545   WT  WT                   WT     WT           WT      WT   WT    WT
#
#      PPM1D     PRKDC  ... NFE2L2 CDC27 PHLDB1 PDE4DIP CDKN1A  AQP7  \
# 0       WT        WT  ...     WT    WT     WT      WT     WT    WT
# 1       WT        WT  ...     WT    WT     WT      WT     WT    WT
# 2       WT        WT  ...     WT    WT     WT      WT     WT    WT
# 3       WT        WT  ...     WT    WT     WT      WT     WT    WT
# 4       WT        WT  ...     WT    WT     WT      WT     WT    WT
# ...    ...       ...  ...    ...   ...    ...     ...    ...   ...
# 2541    WT        WT  ...     WT    WT     WT      WT     WT    WT
# 2542    WT        WT  ...     WT    WT     WT      WT     WT  H58Y
# 2543    WT  P1638Lfs  ...     WT    WT  I858I   P352P     WT    WT
# 2544    WT        WT  ...     WT    WT     WT      WT     WT    WT
# 2545    WT        WT  ...     WT    WT     WT      WT     WT    WT
#
#                                    KALRN BRCA1        CHEK2         AMOT
# 0                                     WT    WT           WT           WT
# 1                                     WT    WT           WT           WT
# 2                                     WT    WT           WT           WT
# 3                                     WT    WT           WT           WT
# 4                                     WT    WT           WT           WT
# ...                                  ...   ...          ...          ...
# 2541                                  WT    WT           WT           WT
# 2542                                  WT    WT           WT           WT
# 2543  R1115C R1087C R1128C R1124C R1137C    WT  K214K K257K  I346N I755N
# 2544                                  WT    WT           WT           WT
# 2545                                  WT    WT           WT           WT
#
# [8747 rows x 186 columns]

# %%
for c in total.columns:
    if total[c].value_counts()['WT'] == len(total):
        print(c)
        total.drop(columns=[c] , inplace=True)
total.columns

# %%
diseaseList = df.SUBCLASS.value_counts().rename_axis('disease').reset_index(name='counts')
diseaseList

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for c in total.columns:
    total[c] = encoder.fit_transform(total[c])

# %%
df = total[:6201]
df_test = total[6201:]

# %%
df
# Out:
#       MEFV  CKB  AKAP13  PCDH7  NCOR2  TNFAIP3  GYS1  SYMPK  PPM1D  PRKDC  \
# 0      197   32     287    215    331      113   120    153     83    386
# 1      197   32     287    215    331      113   120    153     83    386
# 2      197   32     287    215    331      113   120    153     83    386
# 3      197   32     287    215    331      113   120    153     83    386
# 4      197   32     287    215    331      113   120    153     83    386
# ...    ...  ...     ...    ...    ...      ...   ...    ...    ...    ...
# 6196   197   32     287    215    331      113    86    153     83    386
# 6197   197   32     287    215    331      113   120    153     83    386
# 6198   197   32     287    215    331      113   120    153     83    386
# 6199   197   32     287    215    331      113   120    153     83    386
# 6200   139   32     287    215    331      113   120    153     83    386
#
#       ...  NFE2L2  CDC27  PHLDB1  PDE4DIP  CDKN1A  AQP7  KALRN  BRCA1  CHEK2  \
# 0     ...      98    124     174      359      66    54    394    195     97
# 1     ...      98    124     174      359      66    54    394    195     97
# 2     ...      98    124     174      359      66    54    394    195     97
# 3     ...      98    124     174      359      66    54    394    195     97
# 4     ...      98    124     174      359      66    54    394    195     97
# ...   ...     ...    ...     ...      ...     ...   ...    ...    ...    ...
# 6196  ...      98    124     174      359      66    54    394    195     97
# 6197  ...      98    124     174      359      66    54    394    195     97
# 6198  ...      98    124     174      359      66    54    394    195     97
# 6199  ...      98    124     174      359      66    54    394    195     97
# 6200  ...      98    124     174      359      66    54    394    195     97
#
#       AMOT
# 0      155
# 1      155
# 2      155
# 3      155
# 4      155
# ...    ...
# 6196   155
# 6197   155
# 6198   155
# 6199   155
# 6200   155
#
# [6201 rows x 186 columns]

# %%
df_test
# Out:
#       MEFV  CKB  AKAP13  PCDH7  NCOR2  TNFAIP3  GYS1  SYMPK  PPM1D  PRKDC  \
# 0      197   32     287    215    331      113   120    153     83    386
# 1      197   32     116    215    331      113    88    153     83    258
# 2      197   32     287    215    331      113   120    153     83    386
# 3      197   32     287    215    331      113   120    153     83    386
# 4      197   32     287    215    331      113   116    153     83    386
# ...    ...  ...     ...    ...    ...      ...   ...    ...    ...    ...
# 2541   197   32     287    215    331      113   120    153     83    386
# 2542   197   32     287    215    331      113   120    153     83    386
# 2543   197   32       9    104    182      113   120    153     83    231
# 2544   197   32     287    215    331      113   120    153     83    386
# 2545   197   32     287    215    331      113   120    153     83    386
#
#       ...  NFE2L2  CDC27  PHLDB1  PDE4DIP  CDKN1A  AQP7  KALRN  BRCA1  CHEK2  \
# 0     ...      98    124     174      359      66    54    394    195     97
# 1     ...      98    124     174      359      66    54    394    195     97
# 2     ...      98    124     174      359      66    54    394    195     97
# 3     ...      98    124     174      359      66    54    394    195     97
# 4     ...      98    124     174      359      66    54    135    195     97
# ...   ...     ...    ...     ...      ...     ...   ...    ...    ...    ...
# 2541  ...      98    124     174      359      66    54    394    195     97
# 2542  ...      98    124     174      359      66    15    394    195     97
# 2543  ...      98    124      55      188      66    54    256    195     48
# 2544  ...      98    124     174      359      66    54    394    195     97
# 2545  ...      98    124     174      359      66    54    394    195     97
#
#       AMOT
# 0      155
# 1       62
# 2      155
# 3      155
# 4      155
# ...    ...
# 2541   155
# 2542   155
# 2543    54
# 2544   155
# 2545   155
#
# [2546 rows x 186 columns]

# %%
X = df
y = df_target
encoder2 = LabelEncoder()
y = encoder2.fit_transform(y)
y
# Out:
# array([ 8, 19, 20, ...,  4, 22, 20])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=156)
print(X_train.shape, X_test.shape)
# Out:
# (4340, 186) (1861, 186)

# %%
dtrain = xgb.DMatrix(data = X_train, label= y_train)
dtest = xgb.DMatrix(data = X_test, label = y_test)

# %% [markdown]
# #Multi-class classification

# %%
params = {
    'tree_method': 'approx',
    'objective': 'multi:softprob',
    'num_class': df_target.nunique()
}
num_boost_round = 100

dtrain = xgb.DMatrix(data = X_train, label= y_train)
dtest = xgb.DMatrix(data = X_test, label = y_test)
model = xgb.train(params=params, dtrain=dtrain, num_boost_round=num_boost_round,
                  evals=[(dtrain, 'train'), (dtest, 'valid')],
                  verbose_eval=2)
# Out:
# [0]	train-mlogloss:2.63249	valid-mlogloss:2.70635
# [2]	train-mlogloss:2.25574	valid-mlogloss:2.44383
# [4]	train-mlogloss:2.03933	valid-mlogloss:2.31452
# [6]	train-mlogloss:1.89527	valid-mlogloss:2.24006
# [8]	train-mlogloss:1.79068	valid-mlogloss:2.19083
# [10]	train-mlogloss:1.70478	valid-mlogloss:2.15088
# [12]	train-mlogloss:1.63700	valid-mlogloss:2.12670
# [14]	train-mlogloss:1.58259	valid-mlogloss:2.10381
# [16]	train-mlogloss:1.53676	valid-mlogloss:2.09093
# [18]	train-mlogloss:1.49419	valid-mlogloss:2.08269
# [20]	train-mlogloss:1.45821	valid-mlogloss:2.07681
# [22]	train-mlogloss:1.42641	valid-mlogloss:2.07083
# [24]	train-mlogloss:1.39782	valid-mlogloss:2.06776
# [26]	train-mlogloss:1.37100	valid-mlogloss:2.06365
# [28]	train-mlogloss:1.34621	valid-mlogloss:2.06483
# [30]	train-mlogloss:1.32531	valid-mlogloss:2.06235
# [32]	train-mlogloss:1.30413	valid-mlogloss:2.06337
# [34]	train-mlogloss:1.28508	valid-mlogloss:2.06523
# [36]	train-mlogloss:1.26610	valid-mlogloss:2.06422
# [38]	train-mlogloss:1.24846	valid-mlogloss:2.06522
# [40]	train-mlogloss:1.23310	valid-mlogloss:2.06444
# [42]	train-mlogloss:1.21832	valid-mlogloss:2.06447
# [44]	train-mlogloss:1.20486	valid-mlogloss:2.06616
# [46]	train-mlogloss:1.19143	valid-mlogloss:2.06557
# [48]	train-mlogloss:1.17872	valid-mlogloss:2.06709
# [50]	train-mlogloss:1.16671	valid-mlogloss:2.06870
# [52]	train-mlogloss:1.15544	valid-mlogloss:2.06826
# [54]	train-mlogloss:1.14296	valid-mlogloss:2.07202
# [56]	train-mlogloss:1.13251	valid-mlogloss:2.07400
# [58]	train-mlogloss:1.12165	valid-mlogloss:2.07731
# [60]	train-mlogloss:1.11189	valid-mlogloss:2.07908
# [62]	train-mlogloss:1.10172	valid-mlogloss:2.08152
# [64]	train-mlogloss:1.09095	valid-mlogloss:2.08567
# [66]	train-mlogloss:1.08123	valid-mlogloss:2.08849
# [68]	train-mlogloss:1.07219	valid-mlogloss:2.09146
# [70]	train-mlogloss:1.06383	valid-mlogloss:2.09445
# [72]	train-mlogloss:1.05529	valid-mlogloss:2.09673
# [74]	train-mlogloss:1.04651	valid-mlogloss:2.09806
# [76]	train-mlogloss:1.03849	valid-mlogloss:2.10306
# [78]	train-mlogloss:1.03065	valid-mlogloss:2.10697
# [80]	train-mlogloss:1.02292	valid-mlogloss:2.10870
# [82]	train-mlogloss:1.01505	valid-mlogloss:2.11007
# [84]	train-mlogloss:1.00851	valid-mlogloss:2.11241
# [86]	train-mlogloss:1.00193	valid-mlogloss:2.11526
# [88]	train-mlogloss:0.99493	valid-mlogloss:2.11809
# [90]	train-mlogloss:0.98852	valid-mlogloss:2.12257
# [92]	train-mlogloss:0.98197	valid-mlogloss:2.12429
# [94]	train-mlogloss:0.97566	valid-mlogloss:2.12832
# [96]	train-mlogloss:0.96952	valid-mlogloss:2.13119
# [98]	train-mlogloss:0.96334	valid-mlogloss:2.13497
# [99]	train-mlogloss:0.96022	valid-mlogloss:2.13636

# %%
params = {
    'tree_method': 'approx',
    'objective': 'multi:softprob',
    'learning_rate': 0.05
}
num_boost_round = 1000

clf = xgb.XGBClassifier(n_estimators=num_boost_round,early_stopping_rounds=5, **params)
clf.fit(X_train, y_train, 
        eval_set=[(X_train, y_train), (X_test,y_test)],
        verbose=2);
# Out:
# [0]	validation_0-mlogloss:3.14213	validation_1-mlogloss:3.15473
# [2]	validation_0-mlogloss:2.96913	validation_1-mlogloss:3.00604
# [4]	validation_0-mlogloss:2.83640	validation_1-mlogloss:2.89607
# [6]	validation_0-mlogloss:2.72839	validation_1-mlogloss:2.80932
# [8]	validation_0-mlogloss:2.63743	validation_1-mlogloss:2.73784
# [10]	validation_0-mlogloss:2.55895	validation_1-mlogloss:2.67709
# [12]	validation_0-mlogloss:2.48926	validation_1-mlogloss:2.62526
# [14]	validation_0-mlogloss:2.42676	validation_1-mlogloss:2.57929
# [16]	validation_0-mlogloss:2.37070	validation_1-mlogloss:2.53915
# [18]	validation_0-mlogloss:2.31931	validation_1-mlogloss:2.50401
# [20]	validation_0-mlogloss:2.27218	validation_1-mlogloss:2.47178
# [22]	validation_0-mlogloss:2.22857	validation_1-mlogloss:2.44317
# [24]	validation_0-mlogloss:2.18890	validation_1-mlogloss:2.41755
# [26]	validation_0-mlogloss:2.15178	validation_1-mlogloss:2.39364
# [28]	validation_0-mlogloss:2.11715	validation_1-mlogloss:2.37223
# [30]	validation_0-mlogloss:2.08482	validation_1-mlogloss:2.35169
# [32]	validation_0-mlogloss:2.05438	validation_1-mlogloss:2.33382
# [34]	validation_0-mlogloss:2.02561	validation_1-mlogloss:2.31752
# [36]	validation_0-mlogloss:1.99868	validation_1-mlogloss:2.30219
# [38]	validation_0-mlogloss:1.97292	validation_1-mlogloss:2.28730
# [40]	validation_0-mlogloss:1.94880	validation_1-mlogloss:2.27417
# [42]	validation_0-mlogloss:1.92593	validation_1-mlogloss:2.26158
# [44]	validation_0-mlogloss:1.90377	validation_1-mlogloss:2.25045
# [46]	validation_0-mlogloss:1.88327	validation_1-mlogloss:2.23998
# [48]	validation_0-mlogloss:1.86351	validation_1-mlogloss:2.23051
# [50]	validation_0-mlogloss:1.84476	validation_1-mlogloss:2.22165
# [52]	validation_0-mlogloss:1.82666	validation_1-mlogloss:2.21300
# [54]	validation_0-mlogloss:1.80972	validation_1-mlogloss:2.20486
# [56]	validation_0-mlogloss:1.79332	validation_1-mlogloss:2.19734
# [58]	validation_0-mlogloss:1.77775	validation_1-mlogloss:2.18977
# [60]	validation_0-mlogloss:1.76289	validation_1-mlogloss:2.18261
# [62]	validation_0-mlogloss:1.74858	validation_1-mlogloss:2.17561
# [64]	validation_0-mlogloss:1.73494	validation_1-mlogloss:2.16893
# [66]	validation_0-mlogloss:1.72200	validation_1-mlogloss:2.16309
# [68]	validation_0-mlogloss:1.70939	validation_1-mlogloss:2.15704
# [70]	validation_0-mlogloss:1.69698	validation_1-mlogloss:2.15151
# [72]	validation_0-mlogloss:1.68501	validation_1-mlogloss:2.14683
# [74]	validation_0-mlogloss:1.67336	validation_1-mlogloss:2.14233
# [76]	validation_0-mlogloss:1.66222	validation_1-mlogloss:2.13767
# [78]	validation_0-mlogloss:1.65118	validation_1-mlogloss:2.13351
# [80]	validation_0-mlogloss:1.64087	validation_1-mlogloss:2.12921
# [82]	validation_0-mlogloss:1.63070	validation_1-mlogloss:2.12447
# [84]	validation_0-mlogloss:1.62057	validation_1-mlogloss:2.12068
# [86]	validation_0-mlogloss:1.61101	validation_1-mlogloss:2.11684
# [88]	validation_0-mlogloss:1.60175	validation_1-mlogloss:2.11296
# [90]	validation_0-mlogloss:1.59297	validation_1-mlogloss:2.10965
# [92]	validation_0-mlogloss:1.58400	validation_1-mlogloss:2.10663
# [94]	validation_0-mlogloss:1.57514	validation_1-mlogloss:2.10365
# [96]	validation_0-mlogloss:1.56688	validation_1-mlogloss:2.10087
# [98]	validation_0-mlogloss:1.55879	validation_1-mlogloss:2.09823
# [100]	validation_0-mlogloss:1.55088	validation_1-mlogloss:2.09539
# [102]	validation_0-mlogloss:1.54324	validation_1-mlogloss:2.09314
# [104]	validation_0-mlogloss:1.53589	validation_1-mlogloss:2.09037
# [106]	validation_0-mlogloss:1.52866	validation_1-mlogloss:2.08815
# [108]	validation_0-mlogloss:1.52147	validation_1-mlogloss:2.08617
# [110]	validation_0-mlogloss:1.51435	validation_1-mlogloss:2.08414
# [112]	validation_0-mlogloss:1.50758	validation_1-mlogloss:2.08233
# [114]	validation_0-mlogloss:1.50126	validation_1-mlogloss:2.08065
# [116]	validation_0-mlogloss:1.49452	validation_1-mlogloss:2.07953
# [118]	validation_0-mlogloss:1.48795	validation_1-mlogloss:2.07785
# [120]	validation_0-mlogloss:1.48166	validation_1-mlogloss:2.07722
# [122]	validation_0-mlogloss:1.47571	validation_1-mlogloss:2.07623
# [124]	validation_0-mlogloss:1.46968	validation_1-mlogloss:2.07494
# [126]	validation_0-mlogloss:1.46390	validation_1-mlogloss:2.07397
# [128]	validation_0-mlogloss:1.45800	validation_1-mlogloss:2.07288
# [130]	validation_0-mlogloss:1.45222	validation_1-mlogloss:2.07202
# [132]	validation_0-mlogloss:1.44666	validation_1-mlogloss:2.07162
# [134]	validation_0-mlogloss:1.44137	validation_1-mlogloss:2.07064
# [136]	validation_0-mlogloss:1.43636	validation_1-mlogloss:2.07025
# [138]	validation_0-mlogloss:1.43123	validation_1-mlogloss:2.06970
# [140]	validation_0-mlogloss:1.42607	validation_1-mlogloss:2.06959
# [142]	validation_0-mlogloss:1.42141	validation_1-mlogloss:2.06919
# [144]	validation_0-mlogloss:1.41641	validation_1-mlogloss:2.06878
# [146]	validation_0-mlogloss:1.41177	validation_1-mlogloss:2.06794
# [148]	validation_0-mlogloss:1.40713	validation_1-mlogloss:2.06759
# [150]	validation_0-mlogloss:1.40275	validation_1-mlogloss:2.06695
# [152]	validation_0-mlogloss:1.39816	validation_1-mlogloss:2.06609
# [154]	validation_0-mlogloss:1.39377	validation_1-mlogloss:2.06602
# [156]	validation_0-mlogloss:1.38935	validation_1-mlogloss:2.06527
# [158]	validation_0-mlogloss:1.38500	validation_1-mlogloss:2.06454
# [160]	validation_0-mlogloss:1.38082	validation_1-mlogloss:2.06430
# [162]	validation_0-mlogloss:1.37655	validation_1-mlogloss:2.06398
# [164]	validation_0-mlogloss:1.37219	validation_1-mlogloss:2.06401
# [166]	validation_0-mlogloss:1.36808	validation_1-mlogloss:2.06368
# [168]	validation_0-mlogloss:1.36405	validation_1-mlogloss:2.06317
# [170]	validation_0-mlogloss:1.36000	validation_1-mlogloss:2.06252
# [172]	validation_0-mlogloss:1.35585	validation_1-mlogloss:2.06219
# [174]	validation_0-mlogloss:1.35205	validation_1-mlogloss:2.06169
# [176]	validation_0-mlogloss:1.34831	validation_1-mlogloss:2.06129
# [178]	validation_0-mlogloss:1.34450	validation_1-mlogloss:2.06086
# [180]	validation_0-mlogloss:1.34089	validation_1-mlogloss:2.06073
# [182]	validation_0-mlogloss:1.33716	validation_1-mlogloss:2.06036
# [184]	validation_0-mlogloss:1.33361	validation_1-mlogloss:2.05996
# [186]	validation_0-mlogloss:1.33018	validation_1-mlogloss:2.05979
# [188]	validation_0-mlogloss:1.32669	validation_1-mlogloss:2.05959
# [190]	validation_0-mlogloss:1.32338	validation_1-mlogloss:2.05955
# [192]	validation_0-mlogloss:1.31987	validation_1-mlogloss:2.05914
# [194]	validation_0-mlogloss:1.31654	validation_1-mlogloss:2.05898
# [196]	validation_0-mlogloss:1.31332	validation_1-mlogloss:2.05843
# [198]	validation_0-mlogloss:1.31015	validation_1-mlogloss:2.05774
# [200]	validation_0-mlogloss:1.30697	validation_1-mlogloss:2.05739
# [202]	validation_0-mlogloss:1.30370	validation_1-mlogloss:2.05695
# [204]	validation_0-mlogloss:1.30045	validation_1-mlogloss:2.05696
# [206]	validation_0-mlogloss:1.29729	validation_1-mlogloss:2.05628
# [208]	validation_0-mlogloss:1.29414	validation_1-mlogloss:2.05593
# [210]	validation_0-mlogloss:1.29103	validation_1-mlogloss:2.05549
# [212]	validation_0-mlogloss:1.28784	validation_1-mlogloss:2.05536
# [214]	validation_0-mlogloss:1.28479	validation_1-mlogloss:2.05519
# [216]	validation_0-mlogloss:1.28194	validation_1-mlogloss:2.05513
# [218]	validation_0-mlogloss:1.27893	validation_1-mlogloss:2.05528
# [220]	validation_0-mlogloss:1.27616	validation_1-mlogloss:2.05474
# [222]	validation_0-mlogloss:1.27316	validation_1-mlogloss:2.05457
# [224]	validation_0-mlogloss:1.27022	validation_1-mlogloss:2.05454
# [226]	validation_0-mlogloss:1.26733	validation_1-mlogloss:2.05466
# [228]	validation_0-mlogloss:1.26455	validation_1-mlogloss:2.05448
# [230]	validation_0-mlogloss:1.26172	validation_1-mlogloss:2.05425
# [232]	validation_0-mlogloss:1.25905	validation_1-mlogloss:2.05432
# [234]	validation_0-mlogloss:1.25637	validation_1-mlogloss:2.05440

# %%
y_true = y_test
y_pred = clf.predict(X_test)
y_score = clf.predict_proba(X_test)
y_true.shape, y_pred.shape, y_score.shape
# Out:
# ((1861,), (1861,), (1861, 26))

# %%
from sklearn import metrics 
metrics.accuracy_score(y_true, y_pred)
# Out:
# 0.3573347662547018

# %%
from sklearn import metrics 
metrics.accuracy_score(y_true, y_pred)
# Out:
# 0.3573347662547018

# %%
print(metrics.classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.78      0.86        23
#            1       0.45      0.14      0.22        35
#            2       0.29      0.68      0.40       238
#            3       0.24      0.15      0.19        39
#            4       0.62      0.62      0.62        63
#            5       0.33      0.12      0.18        16
#            6       0.36      0.30      0.33       150
#            7       0.36      0.28      0.32        60
#            8       0.23      0.28      0.25       159
#            9       0.15      0.08      0.10       104
#           10       0.68      0.31      0.43        48
#           11       0.26      0.39      0.31        57
#           12       0.36      0.21      0.26        48
#           13       0.27      0.10      0.15        59
#           14       0.31      0.16      0.21        49
#           15       0.27      0.40      0.32        93
#           16       0.25      0.14      0.18        28
#           17       0.31      0.11      0.16        37
#           18       0.28      0.10      0.15        81
#           19       0.38      0.19      0.25        53
#           20       0.79      0.66      0.72        82
#           21       0.29      0.28      0.28       109
#           22       0.39      0.37      0.38        38
#           23       0.78      0.61      0.68       102
#           24       0.50      0.08      0.14        24
#           25       0.58      0.48      0.53        66
#
#     accuracy                           0.36      1861
#    macro avg       0.41      0.31      0.33      1861
# weighted avg       0.38      0.36      0.34      1861

# %%
metrics.roc_auc_score(y_true, y_score, average='weighted', multi_class='ovr')
# Out:
# 0.8629790754169395

# %%
clf.predict(df_test)
# Out:
# array([21, 25,  8, ..., 20, 10,  6])

# %%
res = clf.predict(df_test)

# %%
res = encoder2.inverse_transform(res)

# %%
df_test1 = pd.read_csv('test.csv')
res_df = pd.DataFrame ({'ID' : df_test1['ID'], 'SUBCLASS' : res})
res_df
# Out:
#              ID SUBCLASS
# 0     TEST_0000     STES
# 1     TEST_0001     UCEC
# 2     TEST_0002    KIPAN
# 3     TEST_0003      LGG
# 4     TEST_0004     HNSC
# ...         ...      ...
# 2541  TEST_2541     BLCA
# 2542  TEST_2542     PAAD
# 2543  TEST_2543     SKCM
# 2544  TEST_2544     LAML
# 2545  TEST_2545   GBMLGG
#
# [2546 rows x 2 columns]

# %%
res_df.to_csv('res06-1518-3.csv',index = False)

# %%
pred_probs = xgb_model.predict(dtest)

# %%
import numpy as np
print(np.round(pred_probs[:10], 3))

# %%
preds= [round(x) if x > 0 else 0 for x in pred_probs]

# %%
preds

# %%
for p in preds:
    if p<0:
        print(p)

# %%
encoder.inverse_transform(preds)

# %%
model = RandomForestClassifier(
            n_estimators=50, ## 붓스트랩 샘플 개수 또는 base_estimator 개수
            criterion='entropy', ## 불순도 측도
            max_depth=65, ## 개별 나무의 최대 깊이
            #max_features='sqrt', ## 매 분리시 랜덤으로 뽑을 변수 개수
            #max_samples=1.0, ## 붓스트랩 샘플 비율 => 1이면 학습데이터를 모두 샘플링한다.
            #bootstrap=True, ## 복원 추출,  False이면 비복원 추출
            oob_score=True, ## Out-of-bag 데이터를 이용한 성능 계산
            random_state=100
).fit(X,y)

# %%
## 예측
print(model.predict(X)[:3]) 
print()

# %%
X[:3]

# %%
## 성능 평가
print(model.oob_score_) ## Out-of-bag 성능 평가 점수
print('정확도 : ', model.score(X,y)) ## 테스트 성능 평가 점수(Accuracy)
print()
## 변수 중요도
print(model.feature_importances_)

# %%
## 성능 평가
print(model.oob_score_) ## Out-of-bag 성능 평가 점수
print('정확도 : ', model.score(X,y)) ## 테스트 성능 평가 점수(Accuracy)
print()
## 변수 중요도
print(model.feature_importances_)

# %%
res = model.predict(df_test)
res

# %%
res = model.predict(df_test)
res

# %%
df_test1 = pd.read_csv('test.csv')
res_df = pd.DataFrame ({'ID' : df_test1['ID'], 'SUBCLASS' : res})
res_df

# %%
res_df.to_csv('res04.csv',index = False)

# %%
df[df.SUBCLASS == 'BRCA'].sum().sort_values(ascending=False).str.replace('WT','')

# %%
df[df['SUBCLASS']=='DLBC']

# %%
import numpy as np 
dfs = df[df['SUBCLASS']=='DLBC']
dfs.columns

# %%
for c in dfs.columns:
    dfs[c] = np.where(dfs[c] == 'WT', 0, 1)
dfs

# %%
dfs = df[df['SUBCLASS']=='DLBC']
dfs.apply(lambda x: x(if x=='WT' else x=1))

# %%
for  x in df.iloc[0]:
    if x != 'WT': print(x)

# %%
len(df_test.columns)

# %%
len(df_test)

# %%
df.colu
